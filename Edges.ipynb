# %% [markdown]
# <a href="https://colab.research.google.com/github/drpetros11111/CVision_Hung/blob/main/Edges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

original_image = cv2.imread('/content/bird.jpg', cv2.IMREAD_COLOR)

# we have to transform the image into grayscale
# OpenCV handles BGR instead of RGB
gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

result_image = cv2.Laplacian(gray_image, -1)

cv2_imshow(gray_image)
cv2_imshow(result_image)

# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=600x400>
# <PIL.Image.Image image mode=L size=600x400>
