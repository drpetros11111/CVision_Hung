# %% [markdown]
# <a href="https://colab.research.google.com/github/drpetros11111/CVision_Hung/blob/main/Untitled37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# %%
image =cv2.imread('/content/Albert_Camus.jpg', cv2.IMREAD_GRAYSCALE)

# %%
print(image)
# Out:
# [[ 84  93  99 ... 208 209 208]
#  [ 88  96 101 ... 204 204 204]
#  [ 84  92  97 ... 199 199 199]
#  ...
#  [ 43  42  42 ... 136 135 135]
#  [ 38  40  41 ... 135 135 136]
#  [ 38  40  41 ... 133 133 134]]

# %%
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1024x698>
