# %% [markdown]
# <a href="https://colab.research.google.com/github/drpetros11111/CVision_Hung/blob/main/Sharpen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

original_image = cv2.imread('/content/unsharp_bird.jpg', cv2.IMREAD_COLOR)

# sharpen kernel
# face recognition and we have a blurry CCTV video then we can apply this kernel in order to
# increase the precision of the underlying model
kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

sharpen_image = cv2.filter2D(original_image, -1, kernel)

cv2_imshow(original_image)
cv2_imshow(sharpen_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>
# <PIL.Image.Image image mode=RGB size=600x400>
