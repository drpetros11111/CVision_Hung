# %% [markdown]
# <a href="https://colab.research.google.com/github/drpetros11111/CVision_Hung/blob/main/CV_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# %%
image =cv2.imread('/content/Albert_Camus.jpg', cv2.IMREAD_GRAYSCALE)

# %%
print(image)
# Out:
# [[ 84  93  99 ... 208 209 208]
#  [ 88  96 101 ... 204 204 204]
#  [ 84  92  97 ... 199 199 199]
#  ...
#  [ 43  42  42 ... 136 135 135]
#  [ 38  40  41 ... 135 135 136]
#  [ 38  40  41 ... 133 133 134]]

# %%
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1024x698>

# %%
image =cv2.imread('/content/bird.jpg', cv2.IMREAD_COLOR)

# %%
print(image)
# Out:
# [[[  4  20  49]
#   [  5  21  50]
#   [  7  21  50]
#   ...
#   [  4  22  93]
#   [  4  22  93]
#   [  4  22  93]]
#
#  [[  4  20  49]
#   [  5  21  50]
#   [  7  21  50]
#   ...
#   [  3  20  93]
#   [  3  21  92]
#   [  3  21  92]]
#
#  [[  4  20  49]
#   [  5  21  50]
#   [  4  20  49]
#   ...
#   [  3  20  93]
#   [  3  21  92]
#   [  3  21  92]]
#
#  ...
#
#  [[106 161 112]
#   [107 163 114]
#   [107 166 115]
#   ...
#   [ 60  59 103]
#   [ 57  58 102]
#   [ 56  57 101]]
#
#  [[111 161 113]
#   [110 162 114]
#   [110 165 116]
#   ...
#   [ 62  61 105]
#   [ 61  60 104]
#   [ 61  60 104]]
#
#  [[113 161 113]
#   [113 163 115]
#   [112 164 116]
#   ...
#   [ 64  63 107]
#   [ 63  62 106]
#   [ 62  61 105]]]

# %%
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
print(image.shape)
# Out:
# (400, 600, 3)

# %%
print(np.amax(image))
print(np.amin(image))
# Out:
# 255
# 0
